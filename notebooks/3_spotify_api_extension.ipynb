# %%
import sys
sys.path.append('..')

# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from utils.functions import process_songs_with_spotify

# %%
df_with_spotify = process_songs_with_spotify(
    input_file='../data/3_combined_clean_dataset.csv',
    output_file='../data/4_sp_songs.csv'
)

df_with_spotify.head()
# Out:
# Processing batch 56 of 201
# Error processing bhips don't lie featuring wyclef jean by shakira featuring wyclef jean: 'NoneType' object is not iterable
# WARNING:root:Your application has reached a rate/request limit. Retry will occur after: 65751
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_with_spotify = process_songs_with_spotify(
#       2     input_file='../data/3_combined_clean_dataset.csv',
#       3     output_file='../data/4_sp_songs.csv'
#       4 )
#       6 df_with_spotify.head()
#
# File ~/Ironhack/unit10/ironhack-song-recommender/notebooks/../utils/functions.py:139, in process_songs_with_spotify(input_file, output_file, batch_size)
#     133 try:
#     134     track_info = {
#     135         "title": title,
#     136         "artist": artist,
#     137         "isHot": is_hot
#     138     }
# ...
